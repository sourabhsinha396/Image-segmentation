# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import cv2
import os
import glob
import random
from torch.utils.data import DataLoader
import torch.optim as optim
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
from src import utils
from src import plots
from src import transforms
from src import validation
from src import loaddata
from src import loss
from src import metric
from src import unet256_3x3
from src.classifier import NucleiClassifier

# %%
TRAIN_DIR = "/home/Sourabh/Documents/bima/unet/data/train/"
TEST_DIR = "/home/Sourabh/Documents/bima/unet/data/test/"
FIXED_TRAIN_DIR = "/home/Sourabh/Documents/bima/unet/data/train_fixed/"
CLASS_DISTB_FILE = "/home/Sourabh/Documents/bima/unet/data/classes.csv"
DUMMY = "/home/Sourabh/Documents/bima/unet/data/dummy/"

# %%
test_ids = os.listdir(TEST_DIR)
print(len(test_ids))
dummy_ids = os.listdir(DUMMY)
print(len(dummy_ids))
# Out:
# 65
# 1

# %%
image_dirs, image_masks, image_ids = utils.image_mask_paths(FIXED_TRAIN_DIR)

# %%
class_distb = pd.read_csv(CLASS_DISTB_FILE)

# %%
class_distb.head()
# Out:
#                                             filename foreground background  \
# 0  d32ea6d318626ca14a967d0c1ad3218aebfe636624a8d1...      white      black
# 1  4596961c789d3b41916492918797724fe75128239fefc5...      white      black
# 2  b6edad733399c83c8eb7a59c0d37b54e10cc0d59894e39...      white      black
# 3  831218e6a1a54b23d4be56c5799854e7eb978811b89215...      white      black
# 4  b1e3aeb0c56261c17eb71c747d116057b8da7e8c8a6845...      white      black
#
#    is_train
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
pd.pivot_table(class_distb, index=['is_train', 'background', 'foreground'], aggfunc='count')
# Out:
#                                 filename
# is_train background foreground
# False    black      white             53
#          purple     purple             1
#          white      purple             3
#          yellow     purple             8
# True     black      white            546
#          purple     purple            70
#          white      black             16
#                     purple            38

# %%
class_distb[~class_distb.is_train].groupby(['foreground', 'background']).count().reset_index()
# Out:
#   foreground background  filename  is_train
# 0     purple     purple         1         1
# 1     purple      white         3         3
# 2     purple     yellow         8         8
# 3      white      black        53        53

# %%
train_ids, valid_ids = validation.get_stratified_valid_dirs(class_distb)

# %%
image_p = "{0}{1}/images/{1}.png".format(FIXED_TRAIN_DIR, train_ids[1])
mclass_p = "{}{}/multiclass_mask.png".format(FIXED_TRAIN_DIR, train_ids[1])
assert os.path.isfile(image_p)
assert os.path.isfile(mclass_p)
image = utils.open_image(image_p)

# %% [markdown]
# ## Demonstrating contour generation

# %%
mask_path = "/home/Sourabh/Documents/bima/unet/data/train/0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9"\
    "/masks/47b619fab80e12d48e90530ce859e4b02c46cc82198745bcceafe9b18915931a.png"
mask = utils.open_image(mask_path)

# %%
plots.show_with_size(mask)

# %%
gray = cv2.cvtColor(mask, cv2.COLOR_RGB2GRAY)

# %%
(t, binary) = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY)

# %%
(_, contours, _) = cv2.findContours(binary.astype(np.uint8),
                                    cv2.RETR_EXTERNAL,
                                    cv2.CHAIN_APPROX_SIMPLE)

# %%
contoured_mask = cv2.drawContours(mask, contours, -1, (0, 0, 255), 2)

# %%
plots.show_with_size(contoured_mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plots.show_with_size(contoured_mask2d)

# %%
out = np.clip(contoured_mask2d, 0, 2)

# %%
out.shape
# Out:
# (256, 256)

# %%
out[np.where(out == 0)] = 30
out[np.where(out == 1)] = 110
out[np.where(out == 2)] = 215

# %%
np.unique(out)
# Out:
# array([ 30, 110, 215])

# %%
plt.imsave("test.png", out)

# %%
mask = utils.read2D("test.png")

# %%
np.unique(mask)
# Out:
# array([ 30, 102, 215], dtype=uint8)

# %%
plots.show_with_size(image)

# %%
mclass_mask = utils.read2D(mclass_p)
plots.show_with_size(mclass_mask)

# %%
mclass_mask
# Out:
# array([[ 30,  30,  30, ...,  30,  30,  30],
#        [ 30,  30,  30, ...,  30,  30,  30],
#        [ 30,  30,  30, ...,  30,  30,  30],
#        ...,
#        [215, 215, 102, ...,  30,  30,  30],
#        [215, 215, 215, ...,  30,  30,  30],
#        [215, 215, 215, ...,  30,  30,  30]], dtype=uint8)

# %%
mclass_mask = mclass_mask / 255

# %%
mclass_mask
# Out:
# array([[0.11764706, 0.11764706, 0.11764706, ..., 0.11764706, 0.11764706,
#         0.11764706],
#        [0.11764706, 0.11764706, 0.11764706, ..., 0.11764706, 0.11764706,
#         0.11764706],
#        [0.11764706, 0.11764706, 0.11764706, ..., 0.11764706, 0.11764706,
#         0.11764706],
#        ...,
#        [0.84313725, 0.84313725, 0.4       , ..., 0.11764706, 0.11764706,
#         0.11764706],
#        [0.84313725, 0.84313725, 0.84313725, ..., 0.11764706, 0.11764706,
#         0.11764706],
#        [0.84313725, 0.84313725, 0.84313725, ..., 0.11764706, 0.11764706,
#         0.11764706]])

# %%
np.unique(mclass_mask)
# Out:
# array([0.11764706, 0.4       , 0.84313725])

# %%
ims = [val == mclass_mask for val in np.unique(mclass_mask)]

# %%
fig=plt.figure(figsize=(20, 20))
fig.add_subplot(1, 3, 1)
plt.imshow(ims[0], cmap='gray')
fig.add_subplot(1, 3, 2)
plt.imshow(ims[1], cmap='gray')
fig.add_subplot(1, 3, 3)
plt.imshow(ims[2], cmap='gray')
plt.tight_layout(pad=0.1)

# %%
image = transforms.random_horizontal_flip_transform(image)
image = transforms.fix_resize_transform(image, 256, 256)

# %%
train_data = loaddata.ImageLoader(FIXED_TRAIN_DIR, train_ids, mode='train', transform=transforms.train_augment)
train_dl = DataLoader(train_data, batch_size=32, shuffle=True)
valid_data = loaddata.ImageLoader(FIXED_TRAIN_DIR, valid_ids, mode='valid', transform=transforms.train_augment)
valid_dl = DataLoader(valid_data, batch_size=32, shuffle=True)
test_data = loaddata.ImageLoader(TEST_DIR, test_ids, mode='test', transform=transforms.test_augment)
test_dl = DataLoader(test_data, batch_size=1, shuffle=False)
dummy_data = loaddata.ImageLoader(DUMMY, dummy_ids, mode='train', transform=transforms.train_augment)
dummy_dl = DataLoader(dummy_data, batch_size=4, shuffle=True)

# %%
train, target, id_= train_data[2]

# %%
plots.plot_pair_from_arr(train.data.cpu().numpy().transpose(1,2,0)*255,target.data.cpu().numpy().transpose(1,2,0))

# %%
np.unique(target.data[0])
# Out:
# array([0., 1.], dtype=float32)

# %%
in_shape = (3,256,256)
classes = 3
net = unet256_3x3.UNet256_3x3(in_shape, classes)
criteria = loss.MulticlassBCELoss()
metric = metric.dice_score
optimizer = optim.RMSprop(net.parameters(), lr=0.1)

# %%
classifier = NucleiClassifier(net, criteria, metric, optimizer)

# %%
classifier.train(dummy_dl, valid_dl, 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ca8c2568af21> in <module>()
# ----> 1 classifier.train(dummy_dl, valid_dl, 100)
#
# ~/Documents/bima/unet/src/classifier.py in train(self, train_loader, valid_loader, epochs, threshold)
#     110
#     111         for epoch in range(epochs):
# --> 112             self._run_epoch(train_loader, valid_loader, threshold)
#     113
#     114     def save_model(self, path="/model"):
#
# ~/Documents/bima/unet/src/classifier.py in _run_epoch(self, train_loader, valid_loader, threshold)
#      86         # set model in train mode and run a train pass
#      87         self.net.train()
# ---> 88         train_loss, train_metric = self._train_epoch(train_loader, threshold)
#      89
#      90         # set model in eval mode and validate epoch
#
# ~/Documents/bima/unet/src/classifier.py in _train_epoch(self, train_loader, threshold)
#      71             loss = self.criteria(logits, targets)
#      72             losses.update(loss.data[0], batch_size)
# ---> 73             metric = self.metrics(logits, targets, threshold)
#      74             metrics.update(metric.data[0], batch_size)
#      75
#
# AttributeError: 'NucleiClassifier' object has no attribute 'metrics'

# %%
p = FIXED_TRAIN_DIR + "00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e/masks/"
mask_paths = glob.glob(p + '/*')
mc_mask = np.sum(np.array([utils.multiclass_mask(item) for item in mask_paths]),0)
out = np.clip(mc_mask, 0, 2)

# %%
np.unique(out)
# Out:
# array([0, 1, 2])

# %%
out[np.where(out == 0)] = 30
out[np.where(out == 1)] = 110
out[np.where(out == 2)] = 215

# %%
plt.imsave("here.png", out)

# %%
utils.make_multiclass_mask(p, always=True, mcm_name='temp.png')

# %%
img = cv2.imread("here.png", cv2.IMREAD_GRAYSCALE)

# %%
plots.show_with_size(img)

# %%
np.unique(img)
# Out:
# array([ 30, 102, 215], dtype=uint8)

# %%
img3d = transforms.get_3d_mask(img)

# %%
np.unique(img3d)
# Out:
# array([0, 1])

# %%
back_channel = (img == 30)*1
nuclei_channel = (img == 102)*1
contour_channel = (img == 215)*1

# %%
np.unique(back_channel)
# Out:
# array([0, 1])

# %%
img_out = np.dstack([back_channel, nuclei_channel, contour_channel]).astype(np.uint8)

# %%
plots.show_with_size(img_out*255)

# %%
img_, img_out_r = transforms.fix_resize_transform2(img, img_out, 256,256)

# %%
np.unique(img_out_r)
# Out:
# array([0], dtype=uint8)
